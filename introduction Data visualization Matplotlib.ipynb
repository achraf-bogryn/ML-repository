# %%
# import pandas as pd
# import numpy as np we can use command %matplotlib inline it's like we import all library on jupyter notebook relation with matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
#to dont give us [] we use ; in the end code plt.plot()
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4],[10,20,30,45]);

# %%
X,Y=[1,2,3,4],[11,22,33,44]

# %%
plt.plot(X,Y,'ro');

# %%
#First Method
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
#Second Method
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
plt.show()

# %%
fig,ax=plt.subplots()

# %%
fig,ax=plt.subplots()
ax.plot(X,[40,34,56,78],'bs');

# %% [markdown]
# # Matplotlib example workflow

# %%
#1-Prepare Data
x=np.random.randint(10,size=5)
y=np.random.randint(10,size=5)
#2-Setup plot
fig , ax =plt.subplots(figsize=(10,10))
#3-plot data
ax.plot(x,y);
# customize plot
ax.set(title="simple plot",xlabel="x-axis",ylabel="y-axis");
#save plot to image
fig.savefig("images/simple-plot.png")

# %%
x
# Out:
# array([4, 5, 2, 1, 0])

# %%
y=np.random.randint(10,size=5)

# %%
y
# Out:
# array([7, 5, 4, 5, 7])

# %%
#Zetup plot
fig , ax =plt.subplots(figsize=(10,10))

# %%
#plot data
plt.plot(x,y);

# %%
import numpy as np

# %%
array=np.linspace(0,10,100)

# %%
array[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig , ax =plt.subplots(figsize=(5,5))
ax.plot(array,array**2);
plt.show()

# %%
fig,ax =plt.subplots()
ax.scatter(array,np.exp(array));

# %%
fig,ax =plt.subplots()
ax.scatter(array,np.log(array));
# Out:
# C:\Users\ashraf\AppData\Local\Temp\ipykernel_19504\3717111406.py:2: RuntimeWarning: divide by zero encountered in log
#   ax.scatter(array,np.log(array));

# %%
fig,ax =plt.subplots()
ax.scatter(array,np.cos(array));

# %%
fig,ax =plt.subplots()
ax.scatter(array,np.sin(array));

# %%
pric_fruits={"apple":10,"orange":12,"banana":14,"Grapes":8}
fig,ax=plt.subplots()
ax.bar(pric_fruits.keys(),pric_fruits.values());
ax.set(title="Price differnt fruits",ylabel="Price $");

# %%
fig , ax =plt.subplots()
ax.barh(list(pric_fruits.keys()),list(pric_fruits.values()));

# %%
x=np.random.random(100)

# %%
fig,ax=plt.subplots()
ax.hist(x);

# %%
list1=["A","B","C","D"]
list2=["30","70","100","111"]
fig ,ax = plt.subplots()
ax.barh(list1,list2);

# %%
fig ,ax =plt.subplots()
ax.bar(list1,list2);

# %%
x=np.random.random(50)

# %%
x
# Out:
# array([0.8799817 , 0.06538927, 0.44754737, 0.41792354, 0.36642592,
#        0.23983684, 0.31357287, 0.48064952, 0.32605142, 0.40630092,
#        0.40618756, 0.11541397, 0.3558097 , 0.98285556, 0.79458931,
#        0.72627143, 0.72629018, 0.03822417, 0.38843932, 0.87561927,
#        0.31814273, 0.38296722, 0.10559499, 0.83509704, 0.71290201,
#        0.36259557, 0.63103738, 0.75958837, 0.02236938, 0.25084667,
#        0.0095725 , 0.05387958, 0.06342572, 0.51186337, 0.47996481,
#        0.87426125, 0.76935809, 0.35439763, 0.61785383, 0.25100351,
#        0.71571307, 0.07616495, 0.10160567, 0.05782014, 0.96599844,
#        0.30482045, 0.22925259, 0.80051079, 0.80508584, 0.9057213 ])

# %%
fg ,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(pric_fruits.keys(),pric_fruits.values());
ax[1,1].hist(np.random.randn(100));

# %% [markdown]
# # Ploting from Pandas DataFrame

# %%
import pandas as pd

# %%
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2020",periods=1000))

# %%
ts
# Out:
# 2020-01-01    1.076968
# 2020-01-02    0.315257
# 2020-01-03    0.599873
# 2020-01-04   -0.489968
# 2020-01-05   -0.400754
#                 ...
# 2022-09-22    1.333585
# 2022-09-23   -0.277753
# 2022-09-24    0.043124
# 2022-09-25    2.182064
# 2022-09-26   -1.466183
# Freq: D, Length: 1000, dtype: float64

# %%
ts=ts.cumsum()

# %%
ts
# Out:
# 2020-01-01    1.076968
# 2020-01-02    1.392225
# 2020-01-03    1.992098
# 2020-01-04    1.502129
# 2020-01-05    1.101375
#                 ...
# 2022-09-22   -0.295414
# 2022-09-23   -0.573167
# 2022-09-24   -0.530043
# 2022-09-25    1.652021
# 2022-09-26    0.185838
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[/$/,/.]','')
# Out:
# C:\Users\ashraf\AppData\Local\Temp\ipykernel_19504\3152816120.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[/$/,/.]','')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Add Date column
car_sales["sales Date"]=pd.date_range("01/01/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price sales Date
# 0  Toyota  White         150043      4   400000 2020-01-01
# 1   Honda    Red          87899      4   500000 2020-01-02
# 2  Toyota   Blue          32549      3   700000 2020-01-03
# 3     BMW  Black          11179      5  2200000 2020-01-04
# 4  Nissan  White         213095      4   350000 2020-01-05
# 5  Toyota  Green          99213      4   450000 2020-01-06
# 6   Honda   Blue          45698      4   750000 2020-01-07
# 7   Honda   Blue          54738      4   700000 2020-01-08
# 8  Toyota  White          60000      4   625000 2020-01-09
# 9  Nissan  White          31600      4   970000 2020-01-10

# %%
car_sales["Total Price"]=car_sales["Price"].astype("int").cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price sales Date  Total Price
# 0  Toyota  White         150043      4   400000 2020-01-01       400000
# 1   Honda    Red          87899      4   500000 2020-01-02       900000
# 2  Toyota   Blue          32549      3   700000 2020-01-03      1600000
# 3     BMW  Black          11179      5  2200000 2020-01-04      3800000
# 4  Nissan  White         213095      4   350000 2020-01-05      4150000
# 5  Toyota  Green          99213      4   450000 2020-01-06      4600000
# 6   Honda   Blue          45698      4   750000 2020-01-07      5350000
# 7   Honda   Blue          54738      4   700000 2020-01-08      6050000
# 8  Toyota  White          60000      4   625000 2020-01-09      6675000
# 9  Nissan  White          31600      4   970000 2020-01-10      7645000

# %%
car_sales["Doors"].dtype
# Out:
# dtype('int64')

# %%
car_sales.plot(x="sales Date",y="Total Price");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %% [markdown]
# # Bar

# %%
x=np.random.rand(10,4)

# %%
matrix=pd.DataFrame(x,columns=['a','b','c','d'])

# %%
matrix
# Out:
#           a         b         c         d
# 0  0.254335  0.758642  0.720303  0.998920
# 1  0.417481  0.679967  0.462356  0.210758
# 2  0.122858  0.689216  0.859082  0.563089
# 3  0.178525  0.471606  0.794318  0.852528
# 4  0.216168  0.522214  0.171196  0.908062
# 5  0.156882  0.950040  0.689915  0.951877
# 6  0.479693  0.249635  0.697402  0.533557
# 7  0.622905  0.393479  0.759296  0.838051
# 8  0.639739  0.076239  0.090868  0.708299
# 9  0.566166  0.135245  0.356150  0.564008

# %%
matrix.plot.bar();

# %%
matrix.plot(kind="bar");

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
matrix.plot(kind='bar',stacked=True);

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot(kind="hist",bins=50);

# %%
hear_desease=pd.read_csv("heart-disease.csv")

# %%
hear_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hear_desease["age"].plot(kind="hist",bins=50);

# %%
hear_desease.plot(kind="hist",subplots=True,figsize=(10,20),bins=10);

# %%
hear_desease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=hear_desease[hear_desease["age"] >50]

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(kind="scatter",x="age",y="chol",c="target",s=30
# Out:
#   Cell In[403], line 1
#     over_50.plot(kind="scatter",x="age",y="chol",c="target",s=30
#                                                                 ^
# SyntaxError: incomplete input

# %%
fig, ax = plt.subplots(figsize=(10, 6))
# over_50.plot(kind='scatter', 
#              x="age", 
#              y="chol", 
#              c='target', 
#              ax=ax,
#             s=34);
scatter=ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],s=40)
ax.set_xlim([45, 80]);
ax.set(title="heart deseals level for age less 50 years",xlabel="age",ylabel="cholesstoreul");
ax.legend(*scatter.legend_elements(), title="Target");
ax.axhline(over_50["chol"].mean(),
           linestyle="--");

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter', 
             x="age", 
             y="chol", 
             c='target', 
             ax=ax,
            s=34);
ax.set_xlim([45, 80]);
ax.set(title="heart deseals level for age less 50 years",xlabel="age",ylabel="cholesstoreul");
ax.axhline(over_50["chol"].max(),
           linestyle="--");

# %%
over_50["target"].values

# %%
over_50.head()

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 8))

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")


# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)#we use sharex to share same xlable to all axes
#add data to ax0
scatter=ax0.scatter(over_50["age"],over_50["chol"],c=over_50["target"])
ax0.set(title="Heart deaserse and cholesterol level",ylabel="cholesterol")
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),linestyle="--",color="b");
#add data to ax1
scatter=ax1.scatter(over_50["age"],over_50["thalach"],c=over_50["target"])
ax1.set(title="Heart Disease and Max Heart Rate Levels",ylabel="Max hear rate",xlabel="age")
ax1.legend(*scatter.legend_elements(),title="target");
ax1.axhline(over_50["thalach"].mean(),color="b",linestyle="--");
fig.suptitle('Hear disease analysis',fontsize=17,fontweight="bold");

# %%
plt.style.available

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Odometer (KM)"].plot();

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot()

# %%
car_sales["Price"].plot(kind="hist");

# %%
x=np.random.randn(10,4)
x

# %%
df=pd.DataFrame(x,columns=['A','B','C','D'])

# %%
df

# %%
ax1=df.plot.bar()
ax1.set(title="random number bar graph from DataFrame",xlabel='row number',ylabel="random number")
ax1.legend().set_visible(True)

# %%
ax2=df.plot(kind="barh")

# %%
plt.style.available

# %%
plt.style.use("seaborn-v0_8")
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)#we use sharex to share same xlable to all axes
#add data to ax0
scatter=ax0.scatter(over_50["age"],over_50["chol"],c=over_50["target"])
ax0.set(title="Heart deaserse and cholesterol level",ylabel="cholesterol")
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),linestyle="--",color="b");
#add data to ax1
scatter=ax1.scatter(over_50["age"],over_50["thalach"],c=over_50["target"])
ax1.set(title="Heart Disease and Max Heart Rate Levels",ylabel="Max hear rate",xlabel="age")
ax1.legend(*scatter.legend_elements(),title="target");
ax1.axhline(over_50["thalach"].mean(),color="b",linestyle="--");
fig.suptitle('Hear disease analysis',fontsize=17,fontweight="bold");

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)#we use sharex to share same xlable to all axes
#add data to ax0
scatter=ax0.scatter(over_50["age"],
                    over_50["chol"],
                    c=over_50["target"],
                    cmap="winter")#this is change tho color shema winter or summer
ax0.set(title="Heart deaserse and cholesterol level",ylabel="cholesterol")
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),linestyle="--",color="r");
#add data to ax1
scatter=ax1.scatter(over_50["age"],
                    over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter")
ax1.set(title="Heart Disease and Max Heart Rate Levels",ylabel="Max hear rate",xlabel="age")
ax1.legend(*scatter.legend_elements(),title="target");
ax1.axhline(over_50["thalach"].mean(),color="r",linestyle="--");
fig.suptitle('Hear disease analysis',fontsize=17,fontweight="bold");

# %%
#customizing the y and x axis limitation
scatter=ax0.scatter(over_50["age"],
                    over_50["chol"],
                    c=over_50["target"],
                    cmap="winter")#this is change tho color shema winter or summer
ax0.set(title="Heart deaserse and cholesterol level",
        ylabel="cholesterol")
ax0.legend(*scatter.legend_elements(),
           title="target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--",color="y");
#add data to ax1
scatter=ax1.scatter(over_50["age"],
                    over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter")
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        ylabel="Max hear rate",
        xlabel="age")
ax1.legend(*scatter.legend_elements(),
           title="target");
ax1.axhline(over_50["thalach"].mean(),
            color="y",
            linestyle="--");
ax1.set_ylim([60,200])
#title the figure
fig.suptitle('Hear disease analysis',fontsize=17,fontweight="bold");
